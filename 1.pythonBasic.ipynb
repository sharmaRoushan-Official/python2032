# %%
print("Hello world")
# Out:
# Hello world

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
# Source - https://stackoverflow.com/a/51641071
# Posted by Aymen Alsaadi, modified by community. See post 'Timeline' for change history
# Retrieved 2026-02-24, License - CC BY-SA 4.0

# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 9.4.0
# ipykernel        : 6.30.1
# ipywidgets       : 8.1.7
# jupyter_client   : 8.6.3
# jupyter_core     : 5.8.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.4.6
# nbclient         : 0.10.2
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.4.5
# qtconsole        : not installed
# traitlets        : 5.14.3

# %%
print('Hello world')
# Out:
# Hello world

# %%
# ""  <- Double quote
# ''  <- Single Quote


print('Rohit')
# Out:
# Rohit

# %%
print("Ankit")
# Out:
# Ankit

# %%
print(rohit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(rohit)
#
# NameError: name 'rohit' is not defined

# %%
print("rohit")
# Out:
# rohit

# %%
print("what's your name?")
# Out:
# what's your name?

# %%
print('what"s your name?')
# Out:
# what"s your name?

# %%
import sys
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
print("1233")
# Out:
# 1233

# %%
print("10000")
# Out:
# 10000

# %%
print("!@#$%^")
# Out:
# !@#$%^

# %%
print(rohit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(rohit)
#
# NameError: name 'rohit' is not defined

# %%
print(1000+2) # addition
# Out:
# 1002

# %%
print('1000'+'2')  # Concatenation
# Out:
# 10002

# %%
# 1.String
print("hello world")
print('Hello world')
print('1000')
print('123.56')
print('True')
print("456.25")


# 2. Integer
print(100)
print(12000)
print(450)
print(78)


# 3. Float
print(123.25)
print(100.0)
print(78.23)
print(789.56)


# 4. Boolean
print(True)
print(False)
# Out:
# hello world
# Hello world
# 1000
# 123.56
# True
# 456.25
# 100
# 12000
# 450
# 78
# 123.25
# 100.0
# 78.23
# 789.56
# True
# False

# %% [markdown]
# ### type()

# %%
# 1.String
print("hello world")
print(type("hello world"))
print('Hello world')
print(type('Hello world'))
print('1000')
print(type('1000'))
print('123.56')
print(type('123.56'))
print('True')
print(type('True'))
print("456.25")
print(type("456.25"))


# 2. Integer
print(100)
print(type(100))
print(12000)
print(type(12000))
print(450)
print(type(450))
print(78)
print(type(78))


# 3. Float
print(123.25)
print(type(123.25))
print(100.0)
print(type(100.0))
print(78.23)
print(type(78.23))
print(789.56)
print(type(789.56))


# 4. Boolean
print(True)
print(type(True))
print(False)
print(type(False))
# Out:
# hello world
# <class 'str'>
# Hello world
# <class 'str'>
# 1000
# <class 'str'>
# 123.56
# <class 'str'>
# True
# <class 'str'>
# 456.25
# <class 'str'>
# 100
# <class 'int'>
# 12000
# <class 'int'>
# 450
# <class 'int'>
# 78
# <class 'int'>
# 123.25
# <class 'float'>
# 100.0
# <class 'float'>
# 78.23
# <class 'float'>
# 789.56
# <class 'float'>
# True
# <class 'bool'>
# False
# <class 'bool'>

# %% [markdown]
# ## Data typecasting()

# %% [markdown]
# ## Variable and Expression

# %%
a = 10
print(a)
# Out:
# 10

# %%
a_ = 45
print(a_)
# Out:
# 45

# %%
a1 = 100
print(a1)
# Out:
# 100

# %%
a_1 = 45
print(a_1)
# Out:
# 45

# %%
1_a = 1000
print(1_a)
# Out:
#   Cell In[5], line 1
#     1_a = 1000
#      ^
# SyntaxError: invalid decimal literal

# %%
a_1 = 1000
print(a_1)
# Out:
# 1000

# %%
a_2 = 78
print(a_1)
# Out:
# 78

# %%
print(a_1)
print(a_2)
# Out:
# 1000
# 78

# %%
num = '6'
print(num)
print(type(num))
# Out:
# 6
# <class 'str'>

# %%
num = 6    # int,  float, string
print(num)
print(type(num))



float1 = float(num)
print(float1)
print(type(float1))


str1 = str(num)
print(str1)
print(type(str1))
# Out:
# 6
# <class 'int'>
# 6.0
# <class 'float'>
# 6
# <class 'str'>

# %%
# num = 10.6    # float, int, string

num=10.6    #Float, int, string
print(num)
print(type(num))

int1= int(num)
print(int1)
print(type(int1))

str1 = str(num)
print(str1)
print(type(str1))
# Out:
# 10.6
# <class 'float'>
# 10
# <class 'int'>
# 10.6
# <class 'str'>

# %%
bool1 = True   # int, float, string
print(bool1)
print(type(bool1))

bool2 = False  # int, float, string
# Out:
# True
# <class 'bool'>

# %%
bool1 = True   #int, float, string
print(bool1)
print(type(bool1))

int1= int(bool1)
print(int1)
print(type(int1))

str1= str(bool1)
print(str1)
print(type(str1))
# Out:
# True
# <class 'bool'>
# 1
# <class 'int'>
# True
# <class 'str'>

# %%
bool1 = True   #int, float, string
print(bool1)
print(type(bool1))

float1= float(bool1)
print(float1)
print(type(float1))

int1= int(bool1)
print(int1)
print(type(int1))

str1= str(bool1)
print(str1)
print(type(str1))



bool2 = False   #int, float, string
print(bool2)
print(type(bool2))

int2= int(bool2)
print(int2)
print(type(int2))

float2= float(bool2)
print(float2)
print(type(float2))

str2= str(bool2)
print(str2)
print(type(str2))
# Out:
# True
# <class 'bool'>
# 1.0
# <class 'float'>
# 1
# <class 'int'>
# True
# <class 'str'>
# False
# <class 'bool'>
# 0
# <class 'int'>
# 0.0
# <class 'float'>
# False
# <class 'str'>

# %%
# Expression and Variables 


# Addition

x = 78+74-99-100
print(x)
# Out:
# -47

# %%
# substraction

y1=85-78-99
print(y1)
# Out:
# -92

# %%
# Mulitiplication 

y2 = 78*5
print(y2)
# Out:
# 390

# %%
# division

a1 = 9/2  # division
print(a1)  # it display point value

a2 = 9//2  # Floor division
print(a2)  # it takes only integer value
# Out:
# 4.5
# 4

# %%
# Modulus

a3 = 9%2
print(a3)
# Out:
# 1

# %%
a4 = 9%3
print(a4)
# Out:
# 0

# %%
a5 = 125%3
print(a5)
# Out:
# 2

# %%
# Exponent- Base and Power

x = 2**3 # 2x2x2
print(x)
# Out:
# 8

# %%
x1 = 5**4 # 5x5x5x5
print(x1)
# Out:
# 625

# %% [markdown]
# ## Mathematical Expression

# %%
x = 45+3*89
y = (45+3)*89

print(x)
print(y)

print(x+y)

print(x-y)

print(y-x)

print(x/y)

print(y/x)

print(x*y)

print(y*x)

print(x//y)

print(y//x)

print(y**x)

print(x%y)

print(y%x)
# Out:
# 312
# 4272
# 4584
# -3960
# 3960
# 0.07303370786516854
# 13.692307692307692
# 1332864
# 1332864
# 0
# 13
# ...
# 312
# 216
