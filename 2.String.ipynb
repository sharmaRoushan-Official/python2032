# %% [markdown]
# # 2. String Data type

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
print("1235668+10")
# Out:
# 1235668+10

# %%
print("!@#%$^%^")
# Out:
# !@#%$^%^

# %%
message = 10
print(message)
# Out:
# 10

# %%
msg = "Hello world"
print(msg)
# Out:
# Hello world

# %% [markdown]
# # Indexing of a string

# %%
msg = "Hello world"
print(msg)
# Out:
# Hello world

# %%
# positive Indexing
print(msg[0])
print(msg[1])
print(msg[2])
print(msg[3])
print(msg[4])
print(msg[5])
print(msg[6])
print(msg[7])
print(msg[8])
print(msg[9])
print(msg[10])
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
# Negative Indexing

print(msg[-1])
print(msg[-2])
print(msg[-3])
print(msg[-4])
print(msg[-5])
print(msg[-6])
print(msg[-7])
print(msg[-8])
print(msg[-9])
print(msg[-10])
print(msg[-11])
# Out:
# d
# l
# r
# o
# w
#
# o
# l
# l
# e
# H

# %%
# to count total length of string
print(len(msg))
# Out:
# 11

# %%
msg = "Hello world"
print(msg)
# Out:
# Hello world

# %% [markdown]
# # Slicing of string

# %%
msg1 = msg[0:5]  # n-1 = 5-1 = 4
print(msg1)
# Out:
# Hello

# %%
msg2 = msg[6:11]
print(msg2)
# Out:
# world

# %%
msg1 = msg[:5]  # n-1 = 5-1 = 4
print(msg1)
# Out:
# Hello

# %%
msg2 = msg[6:]
print(msg2)
# Out:
# world

# %% [markdown]
# ## Striding value

# %%
msg = "Hello world"
print(msg)
# Out:
# Hello world

# %%
msg[::2]  # 2-1 = 1
# Out:
# 'Hlowrd'

# %%
msg[::3]
# Out:
# 'Hlwl'

# %%
msg[::4]
# Out:
# 'Hor'

# %%
msg = "Hello world"
print(msg)


msg2 = msg[6::2]
print(msg2)

msg1 = msg[:5:2]
print(msg1)
# Out:
# Hello world
# wrd
# Hlo

# %%
msg = "Hello World"
print(msg)
# Out:
# Hello World

# %%
msg[0:5:2]
# Out:
# 'Hlo'

# %%
msg[:5:2]
# Out:
# 'Hlo'

# %% [markdown]
# # Concatenation of String

# %%
firstname = "Ankit"
surname = " Chouksey"

fullname = firstname+surname
print(fullname)
# Out:
# Ankit Chouksey

# %%
msg = "Hello world"
question = "How many people are living on the earth?"

print(msg+question)
# Out:
# Hello worldHow many people are living on the earth?

# %% [markdown]
# ## Escape Sequence

# %%
print("Hello world\nHow many people are living on the earth?") # \n - new line
# Out:
# Hello world
# How many people are living on the earth?

# %%
print("///")
# Out:
# ///

# %%
print("\\\\\\")
# Out:
# \\\

# %%
print("Hello world\tHow many people are living on the earth?") # \n - new line
# Out:
# Hello world	How many people are living on the earth?

# %% [markdown]
# | Escape Sequence | Description               | Example                    | Output           |
# | --------------- | ------------------------- | -------------------------- | ---------------- |
# | `\\`            | Backslash                 | `print("Hello\\World")`    | Hello\World      |
# | `\'`            | Single Quote              | `print('It\'s Python')`    | It's Python      |
# | `\"`            | Double Quote              | `print("She said \"Hi\"")` | She said "Hi"    |
# | `\n`            | New Line                  | `print("Hello\nWorld")`    | Hello <br> World |
# | `\t`            | Horizontal Tab            | `print("Hello\tWorld")`    | Hello World      |
# | `\r`            | Carriage Return           | `print("Hello\rWorld")`    | World            |
# | `\b`            | Backspace                 | `print("Hell\b o")`        | Hel o            |
# | `\f`            | Form Feed                 | `print("Hello\fWorld")`    | Hello World      |
# | `\v`            | Vertical Tab              | `print("Hello\vWorld")`    | Hello World      |
# | `\a`            | Bell / Alert Sound        | `print("\a")`              | System beep      |
# | `\ooo`          | Octal Value               | `print("\110")`            | H                |
# | `\xhh`          | Hexadecimal Value         | `print("\x48")`            | H                |
# | `\N{name}`      | Unicode Character by Name | `print("\N{HEART SUIT}")`  | ♥                |
# | `\uXXXX`        | Unicode (16-bit)          | `print("\u2764")`          | ❤                |
# | `\UXXXXXXXX`    | Unicode (32-bit)          | `print("\U0001F600")`      | 😀               |

# %% [markdown]
# ### Operators in Python
#
# * `Arithematic` Operator - [+,-,*,/,//,%,**]
#    * `Unary` Operator- [++,--,**,]
#    * `Binary` Operator- [+,-,*,/,//,%]
# * `Logical` Operator - [AND, OR, NOT]
# * `Comparison` Operator- [<,>,<=,>=,!=,==]
# * `Identity` Operator- [is, isnot]
# * `Membership` Operator- [in, not in]

# %% [markdown]
# ## String Operations

# %%
message = "hello PYThon"

print('Original String:',message)


# .upper()

msg1 = message.upper()
print("After Upper Case:",msg1)


# .lower()
msg2 = message.lower()
print("After Lower Case:",msg2)



# .title()

msg3 = message.title()
print("After Title Case:",msg3)


# .capitalize()
msg4 = message.capitalize()
print("After Capitalize:",msg4)
# Out:
# Original String: hello PYThon
# After Upper Case: HELLO PYTHON
# After Lower Case: hello python
# After Title Case: Hello Python
# After Capitalize: Hello python

# %%
msg1 = "Hello World"

print(msg1.find('W'))
print(msg1.find('llo'))
print(msg1.find('el'))
# Out:
# 6
# 2
# 1

# %%
print(msg1.find('jlajjlkfa'))
# Out:
# -1

# %%
msg2 = "Hello world"
print('Original Text:',msg2)


msg3 = msg2.replace('world',"Ankit")
print("After Replace:",msg3)
# Out:
# Original Text: Hello world
# After Replace: Hello Ankit

# %%
# Center 
message = "Hello World"

message.center(50,'-')
# Out:
# '-------------------Hello World--------------------'

# %%
50-11
# Out:
# 39

# %%
39/2
# Out:
# 19.5

# %%
message.center(50,'*')
# Out:
# '*******************Hello World********************'
