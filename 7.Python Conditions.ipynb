# %% [markdown]
# # 7. Conditions in Python
#
#
# ### 1. What is a condition Statement?
#
#  * A `conditional statement` allows a program to make decidions based on conditions(True/False).
#
#  * In Python, we use:
#
#    * if
#    * elif
#    * else

# %% [markdown]
# ### 2. Basic If Statement
#
# ✔️ Syntax

# %% [raw]
# if condition:
#     # code executes if condition is True

# %%
age = 30    # variable which contains 18 value

if age>=18:# condition [if condition is true/False]
    print("You are elegible to vote")  # statement  [executed/Not executed]
    # (Indentation)
# Out:
# You are elegible to vote

# %% [markdown]
# Key Points:
#
# * Condition Must return True/False
# * Indentation is mandatory
# * No parentheses required(unlike c/Java)

# %%
age>=18
# Out:
# True

# %% [markdown]
# ## 3. if-else statement
#
#
# ✔️ syntax

# %% [raw]
# if condition:
#     # True Block
# else:
#     # False Bolck

# %%
age = 15

if age>=18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %% [markdown]
# Key Points
#
# * else executes when condition is false
# * Only one else allowed per if

# %% [markdown]
# ### 4. ladder if-elif-else Ladder
#
# ✔️ syntax
#
# if condition 1:
#
#     # block 1
#
# elif condition 2:
#
#     # block 2
#
# elif condition 3:
#
#     # block 3
#
# else:
#
#     # default block

# %%
marks = 91  # A,B,C,D

if marks>=90:
    print("Grade A")
elif marks>=70:
    print("Grade B")
elif marks>=50:
    print("Grade C")
elif marks>=40:
    print("Grde D")
else:
    print("Fail")
# Out:
# Grade A

# %% [markdown]
# ### Key points
# * Multiple conditions can be checked
# * Only first True condition executes
# * else is optional.

# %% [markdown]
# ### 5. Nested if statements

# %%
age = 20

citizen = not(not(not(False)))

name = "rohit"
if age>=18:
    if citizen:
        print("Elegible to vote")
        if name == "Rohit":
            print("Myself Rohit")
        else:
            print("Ankit")
    else:
        print("Not a Citizen")
else:
    print("Under Age")
# Out:
# Elegible to vote
# Ankit

# %%
not(False)
# Out:
# True

# %%
not(not(False))
# Out:
# False

# %%
not(not(not(False)))
# Out:
# True

# %%
# display even or odd number from user user input number: user input enter positive number

num = int(input("Enter any number: "))
print(num)

if num>0:
    if num%2==0:
        print("Even Number")
    else:
        print("Odd Number")
else:
    print("You enter negative number")
# Out:
# Enter any number:  78
# 78
# Even Number

# %%
78%2
# Out:
# 0
